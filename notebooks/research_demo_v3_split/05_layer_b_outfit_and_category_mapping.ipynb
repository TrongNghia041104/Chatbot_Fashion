# %% [markdown]
# # 05 - Layer B Outfit Rule Debug (Legacy)
#
# > Notebook này đã được chuyển sang khu vực lưu trữ để luồng đọc chính ngắn gọn hơn.
#
# - Luồng đang sử dụng: [`05_layer_b_outfit_and_category_mapping_v2.ipynb`](05_layer_b_outfit_and_category_mapping_v2.ipynb)
# - Bản đầy đủ để đối chiếu lịch sử: [`archive/05_layer_b_outfit_and_category_mapping_legacy.ipynb`](archive/05_layer_b_outfit_and_category_mapping_legacy.ipynb)
#
# Không có code thực thi trong trang điều hướng này, vì vậy người đọc sẽ không vô tình chạy nhầm pipeline legacy.

# %% [markdown]
# > **LEGACY REFERENCE:** Bản này chỉ giữ để đối chiếu. Với luồng hiện tại, hãy đọc/chạy `05_layer_b_outfit_and_category_mapping_v2.ipynb`; production dùng `app/core/outfit.py`.

# %% [markdown]
# > **Ranh giới kiến trúc:** notebook này không định nghĩa top-level router. Các helper tại đây chỉ suy ra constraint/retrieval goal bên trong một pipeline đã được `app/core/intent.py` chọn. Vì vậy chúng không làm tăng số business intent hay execution route.
