# %% [markdown]
# # 1. Import thư viện

# %%
# !pip install -r requirment.txt
# Out:
# Requirement already satisfied: langchain-huggingface in c:\users\dell\anaconda3\lib\site-packages (from -r requirment.txt (line 1)) (1.2.2)
# Requirement already satisfied: langchain-qdrant in c:\users\dell\anaconda3\lib\site-packages (from -r requirment.txt (line 2)) (1.1.0)
# Requirement already satisfied: qdrant-client in c:\users\dell\anaconda3\lib\site-packages (from -r requirment.txt (line 3)) (1.17.1)
# Requirement already satisfied: langchain-core in c:\users\dell\anaconda3\lib\site-packages (from -r requirment.txt (line 4)) (1.3.2)
# Collecting langchain-ollama (from -r requirment.txt (line 5))
#   Downloading langchain_ollama-1.1.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langchain-community in c:\users\dell\anaconda3\lib\site-packages (from -r requirment.txt (line 6)) (0.4.1)
# Requirement already satisfied: underthesea in c:\users\dell\anaconda3\lib\site-packages (from -r requirment.txt (line 7)) (9.2.11)
# Requirement already satisfied: tqdm in c:\users\dell\anaconda3\lib\site-packages (from -r requirment.txt (line 8)) (4.66.4)
# Collecting redis (from -r requirment.txt (line 9))
#   Downloading redis-7.4.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: langchain-google-genai in c:\users\dell\anaconda3\lib\site-packages (from -r requirment.txt (line 10)) (4.2.2)
# Requirement already satisfied: python-dotenv in c:\users\dell\anaconda3\lib\site-packages (from -r requirment.txt (line 11)) (1.2.1)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in c:\users\dell\anaconda3\lib\site-packages (from langchain-huggingface->-r requirment.txt (line 1)) (1.9.2)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in c:\users\dell\anaconda3\lib\site-packages (from langchain-huggingface->-r requirment.txt (line 1)) (0.22.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\dell\anaconda3\lib\site-packages (from langchain-qdrant->-r requirment.txt (line 2)) (2.12.5)
# Requirement already satisfied: grpcio>=1.41.0 in c:\users\dell\anaconda3\lib\site-packages (from qdrant-client->-r requirment.txt (line 3)) (1.76.0)
# Requirement already satisfied: httpx>=0.20.0 in c:\users\dell\anaconda3\lib\site-packages (from httpx[http2]>=0.20.0->qdrant-client->-r requirment.txt (line 3)) (0.28.1)
# Requirement already satisfied: numpy>=1.26 in c:\users\dell\anaconda3\lib\site-packages (from qdrant-client->-r requirment.txt (line 3)) (1.26.4)
# Requirement already satisfied: portalocker<4.0,>=2.7.0 in c:\users\dell\anaconda3\lib\site-packages (from qdrant-client->-r requirment.txt (line 3)) (3.2.0)
# Requirement already satisfied: protobuf>=3.20.0 in c:\users\dell\anaconda3\lib\site-packages (from qdrant-client->-r requirment.txt (line 3)) (5.29.6)
# Requirement already satisfied: urllib3<3,>=1.26.14 in c:\users\dell\anaconda3\lib\site-packages (from qdrant-client->-r requirment.txt (line 3)) (2.2.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core->-r requirment.txt (line 4)) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.10 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core->-r requirment.txt (line 4)) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core->-r requirment.txt (line 4)) (0.6.9)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core->-r requirment.txt (line 4)) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core->-r requirment.txt (line 4)) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core->-r requirment.txt (line 4)) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core->-r requirment.txt (line 4)) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core->-r requirment.txt (line 4)) (0.14.0)
# Collecting ollama<1.0.0,>=0.6.1 (from langchain-ollama->-r requirment.txt (line 5))
#   Downloading ollama-0.6.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\dell\anaconda3\lib\site-packages (from langchain-community->-r requirment.txt (line 6)) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\dell\anaconda3\lib\site-packages (from langchain-community->-r requirment.txt (line 6)) (2.0.30)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\dell\anaconda3\lib\site-packages (from langchain-community->-r requirment.txt (line 6)) (2.32.5)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\dell\anaconda3\lib\site-packages (from langchain-community->-r requirment.txt (line 6)) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\dell\anaconda3\lib\site-packages (from langchain-community->-r requirment.txt (line 6)) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\dell\anaconda3\lib\site-packages (from langchain-community->-r requirment.txt (line 6)) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\dell\anaconda3\lib\site-packages (from langchain-community->-r requirment.txt (line 6)) (0.4.3)
# Requirement already satisfied: Click>=6.0 in c:\users\dell\anaconda3\lib\site-packages (from underthesea->-r requirment.txt (line 7)) (8.1.7)
# Requirement already satisfied: joblib in c:\users\dell\anaconda3\lib\site-packages (from underthesea->-r requirment.txt (line 7)) (1.4.2)
# Requirement already satisfied: underthesea_core>=3.3.0 in c:\users\dell\anaconda3\lib\site-packages (from underthesea->-r requirment.txt (line 7)) (3.3.0)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\lib\site-packages (from tqdm->-r requirment.txt (line 8)) (0.4.6)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\dell\anaconda3\lib\site-packages (from langchain-google-genai->-r requirment.txt (line 10)) (1.2.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.65.0 in c:\users\dell\anaconda3\lib\site-packages (from langchain-google-genai->-r requirment.txt (line 10)) (1.75.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\dell\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirment.txt (line 6)) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\dell\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirment.txt (line 6)) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\dell\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirment.txt (line 6)) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\dell\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirment.txt (line 6)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\dell\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirment.txt (line 6)) (1.9.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\dell\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community->-r requirment.txt (line 6)) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\dell\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community->-r requirment.txt (line 6)) (0.9.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\dell\anaconda3\lib\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai->-r requirment.txt (line 10)) (4.13.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in c:\users\dell\anaconda3\lib\site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai->-r requirment.txt (line 10)) (2.50.0)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in c:\users\dell\anaconda3\lib\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai->-r requirment.txt (line 10)) (16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\dell\anaconda3\lib\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai->-r requirment.txt (line 10)) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\dell\anaconda3\lib\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai->-r requirment.txt (line 10)) (1.3.0)
# Requirement already satisfied: certifi in c:\users\dell\anaconda3\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client->-r requirment.txt (line 3)) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\dell\anaconda3\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client->-r requirment.txt (line 3)) (1.0.2)
# Requirement already satisfied: idna in c:\users\dell\anaconda3\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client->-r requirment.txt (line 3)) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\dell\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client->-r requirment.txt (line 3)) (0.14.0)
# Requirement already satisfied: h2<5,>=3 in c:\users\dell\anaconda3\lib\site-packages (from httpx[http2]>=0.20.0->qdrant-client->-r requirment.txt (line 3)) (4.3.0)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\dell\anaconda3\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface->-r requirment.txt (line 1)) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\dell\anaconda3\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface->-r requirment.txt (line 1)) (2024.3.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in c:\users\dell\anaconda3\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface->-r requirment.txt (line 1)) (1.4.3)
# Requirement already satisfied: typer in c:\users\dell\anaconda3\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface->-r requirment.txt (line 1)) (0.21.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\dell\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core->-r requirment.txt (line 4)) (2.1)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\users\dell\anaconda3\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community->-r requirment.txt (line 6)) (1.1.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\dell\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core->-r requirment.txt (line 4)) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\dell\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core->-r requirment.txt (line 4)) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\dell\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core->-r requirment.txt (line 4)) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\dell\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core->-r requirment.txt (line 4)) (0.25.0)
# Requirement already satisfied: pywin32>=226 in c:\users\dell\anaconda3\lib\site-packages (from portalocker<4.0,>=2.7.0->qdrant-client->-r requirment.txt (line 3)) (305.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dell\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-qdrant->-r requirment.txt (line 2)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\dell\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-qdrant->-r requirment.txt (line 2)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\dell\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-qdrant->-r requirment.txt (line 2)) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community->-r requirment.txt (line 6)) (2.0.4)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\dell\anaconda3\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community->-r requirment.txt (line 6)) (3.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dell\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai->-r requirment.txt (line 10)) (0.2.8)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\dell\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai->-r requirment.txt (line 10)) (42.0.5)
# Requirement already satisfied: hyperframe<7,>=6.1 in c:\users\dell\anaconda3\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client->-r requirment.txt (line 3)) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in c:\users\dell\anaconda3\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client->-r requirment.txt (line 3)) (4.1.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\dell\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community->-r requirment.txt (line 6)) (1.0.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\dell\anaconda3\lib\site-packages (from typer->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface->-r requirment.txt (line 1)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\dell\anaconda3\lib\site-packages (from typer->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface->-r requirment.txt (line 1)) (13.3.5)
# Requirement already satisfied: cffi>=1.12 in c:\users\dell\anaconda3\lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai->-r requirment.txt (line 10)) (1.16.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\dell\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai->-r requirment.txt (line 10)) (0.4.8)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\dell\anaconda3\lib\site-packages (from rich>=10.11.0->typer->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface->-r requirment.txt (line 1)) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dell\anaconda3\lib\site-packages (from rich>=10.11.0->typer->huggingface-hub<2.0.0,>=0.33.4->langchain-hugging
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ---------------------------------- ---- 358.4/409.8 kB 17.3 kB/s eta 0:00:03
#    ----------------------------------- --- 368.6/409.8 kB 16.7 kB/s eta 0:00:03
#    ----------------------------------- --- 368.6/409.8 kB 16.7 kB/s eta 0:00:03
#    ----------------------------------- --- 368.6/409.8 kB 16.7 kB/s eta 0:00:03
#    ----------------------------------- --- 368.6/409.8 kB 16.7 kB/s eta 0:00:03
#    ----------------------------------- --- 368.6/409.8 kB 16.7 kB/s eta 0:00:03
#    ----------------------------------- --- 368.6/409.8 kB 16.7 kB/s eta 0:00:03
#    ----------------------------------- --- 368.6/409.8 kB 16.7 kB/s eta 0:00:03
#    ----------------------------------- --- 368.6/409.8 kB 16.7 kB/s eta 0:00:03
#    ----------------------------------- --- 368.6/409.8 kB 16.7 kB/s eta 0:00:03
#    ----------------------------------- --- 368.6/409.8 kB 16.7 kB/s eta 0:00:03
#    ----------------------------------- --- 368.6/409.8 kB 16.7 kB/s eta 0:00:03
#    ----------------------------------- --- 368.6/409.8 kB 16.7 kB/s eta 0:00:03
#    ------------------------------------- - 389.1/409.8 kB 17.2 kB/s eta 0:00:02
#    ------------------------------------- - 389.1/409.8 kB 17.2 kB/s eta 0:00:02
#    ------------------------------------- - 389.1/409.8 kB 17.2 kB/s eta 0:00:02
#    ------------------------------------- - 389.1/409.8 kB 17.2 kB/s eta 0:00:02
#    ------------------------------------- - 389.1/409.8 kB 17.2 kB/s eta 0:00:02
#    ------------------------------------- - 389.1/409.8 kB 17.2 kB/s eta 0:00:02
#    ------------------------------------- - 389.1/409.8 kB 17.2 kB/s eta 0:00:02
#    ------------------------------------- - 389.1/409.8 kB 17.2 kB/s eta 0:00:02
#    ------------------------------------- - 389.1/409.8 kB 17.2 kB/s eta 0:00:02
#    ------------------------------------- - 389.1/409.8 kB 17.2 kB/s eta 0:00:02
#    ------------------------------------- - 389.1/409.8 kB 17.2 kB/s eta 0:00:02
#    ------------------------------------- - 389.1/409.8 kB 17.2 kB/s eta 0:00:02
#    ------------------------------------- - 389.1/409.8 kB 17.2 kB/s eta 0:00:02
#    ------------------------------------- - 389.1/409.8 kB 17.2 kB/s eta 0:00:02
#    ------------------------------------- - 389.1/409.8 kB 17.2 kB/s eta 0:00:02
#    ------------------------------------- - 389.1/409.8 kB 17.2 kB/s eta 0:00:02
#    ------------------------------------- - 389.1/409.8 kB 17.2 kB/s eta 0:00:02
#    ------------------------------------- - 389.1/409.8 kB 17.2 kB/s eta 0:00:02
#    ------------------------------------- - 389.1/409.8 kB 17.2 kB/s eta 0:00:02
#    ------------------------------------- - 389.1/409.8 kB 17.2 kB/s eta 0:00:02
#    ------------------------------------- - 389.1/409.8 kB 17.2 kB/s eta 0:00:02
#    --------------------------------------- 409.8/409.8 kB 17.4 kB/s eta 0:00:00
# Downloading ollama-0.6.2-py3-none-any.whl (15 kB)
# Installing collected packages: redis, ollama, langchain-ollama
# Successfully installed langchain-ollama-1.1.0 ollama-0.6.2 redis-7.4.0

# %%
"""
Các dòng code bên dưới dùng để import các thư viện thiết yếu để xây dựng mô hình RAG
"""
import json
import sys
import uuid
import os
import time
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_core.embeddings import Embeddings
from langchain_qdrant import QdrantVectorStore
from qdrant_client import QdrantClient
from qdrant_client.http.models import Distance, VectorParams
from langchain_core.documents import Document
from underthesea import word_tokenize
from tqdm import tqdm
from langchain_ollama import ChatOllama
from langchain_classic.chains import create_retrieval_chain
from langchain_classic.chains.combine_documents import create_stuff_documents_chain
from langchain_community.chat_message_histories import RedisChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_classic.chains import create_history_aware_retriever
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate, MessagesPlaceholder
from langchain_core.callbacks import BaseCallbackHandler

# %% [markdown]
# # 2. Chunking các metadata của sản phẩm thời trang

# %%
def process_fashion_metadata(file_path):
    """
    Hàm này được sử dụng để đọc file JSONL và chuyển đổi thành danh sách các LangChain Documents
    """
    documents = []

    # Mở và đọc từng dòng trong file JSONL
    with open(file_path, "r", encoding="utf-8") as f:
        for line in f:
            if not line.strip(): # Kiểm tra các dòng trống và bỏ qua nó
                continue
            item = json.loads(line) # Load từng dòng json

            # Bước 1: Xử lý metadata sản phẩm để lấy ra các trường quan trọng và đặt nó cùng với "Bước 2"
            # Trích xuất danh sách link ảnh từ mảng images
            image_urls = [img.get("large") for img in item.get("images", []) if "large" in img]

            # Lấy các thông tin metadata của sản phẩm 
            metadata = {
                "product_id": item.get("product_id", ""),
                "category": item.get("category", ""),
                "department": item.get("department", ""),
                "brand": item.get("brand", ""),
                "price": item.get("price", 0),
                "images": image_urls
            }

            # Bước 2: Xử lý theo hướng văn bản hóa dữ liệu có cấu trúc
            # Lấy thông tin details từ metadata của sản phẩm
            details = item.get("details", {})
            main_color = details.get("main_color", "Không có thông tin về màu sắc")
            material = details.get("material", "Không có thông tin về chất liệu")
            size = details.get("size", "Không có thông tin về kích thước")
            pattern = details.get("pattern", "Không có thông tin về họa tiết")
            
            # Khung văn bản mô tả sản phẩm
            page_content = (
                f"Sản phẩm {item.get('title', 'Không có tên sản phẩm')} thuộc danh mục {item.get('category', '')} "
                f"dành cho {item.get('department', '')}. "
                f"Thương hiệu: {item.get('brand', 'Không có thông tin về thương hiệu')}. "
                f"Mức giá: {item.get('price', 0)} VNĐ. "
                f"Đặc điểm chi tiết: có các loại màu sắc: {main_color}, chất liệu: {material}, kích cỡ: {size}, họa tiết: {pattern}. "
                f"Phù hợp sử dụng cho {item.get('season', '')} và các dịp {item.get('occasion', '')}. "
                f"Mô tả chi tiết: {item.get('description', '')}"
            )
            
            # Bước 3: Tạo LangChain Documents
            doc = Document(page_content=page_content, metadata=metadata)
            documents.append(doc)
            """
            Sau khi tạo xong LangChain Documents thì đối tượng Document nó sẽ có 2 thành phần sau:
            - page_content (string): Đây chính là phần văn bản đã được "văn bản hóa" từ dữ liệu thô có cấu trúc ở "Bước 2". Phần này sau đó sẽ
              đi qua một mô hình Embedding để tạo vector ngữ nghĩa.
            - metadata (dict): Đây là một từ điển chứa các thông tin bổ trợ. Phần này sẽ được giữ nguyên cấu trúc của nó.
            """

        return documents

def process_all_directory(directory_path):
    """
    Hàm lặp qua tất cả các file .jsonl trong một thư mục và gộp data lại.
    """
    all_documents = []
    
    # Duyệt qua tất cả các file có trong thư mục
    for filename in sorted(os.listdir(directory_path)):
        # Chỉ xử lý những file có đuôi là .jsonl
        if filename.endswith(".jsonl"):
            # Tạo đường dẫn tuyệt đối cho từng file
            file_path = os.path.join(directory_path, filename)
            
            print(f"[THÔNG BÁO] Đang đọc file: {filename}...")
            
            # Gọi lại hàm process_fashion_metadata(file_path) đã được định nghĩa ở phía trên
            docs = process_fashion_metadata(file_path)
            
            # LƯU Ý QUAN TRỌNG: Dùng .extend() để gộp các list lại với nhau
            # Không dùng .append() vì nó sẽ tạo ra list lồng list
            all_documents.extend(docs)
            
    return all_documents

# %% [markdown]
# # 3. Sử dụng mô hình Embedding để xử lý các Chunks vào lưu vào Qdrant vector DB

# %%
# class VietnameseSegmentedEmbeddings(Embeddings):
#     # Hàm này dùng để khởi tạo mô hình Embedding
#     def __init__(self, model_name="VoVanPhuc/sup-SimCSE-VietNamese-phobert-base"):
#         self.hf_embeddings = HuggingFaceEmbeddings(model_name=model_name)
        
#     # Hàm này nhận đầu vào là text và dùng word_tokenize của underthesea để thực hiện tách từ và trả về từ đã tách
#     def _segment_text(self, text: str) -> str:
#         if not text:
#             return ""
#         return word_tokenize(text, format="text")

#     # Hàm này sử dụng mô hình embedding đã khởi tạo để vector hóa dữ liệu
#     def embed_documents(self, texts: list[str]) -> list[list[float]]:
#         segmented_texts = [self._segment_text(text) for text in texts]
#         return self.hf_embeddings.embed_documents(segmented_texts)

#     # Hàm này sử dụng mô hình embedding đã khởi tọa để vector hóa câu truy vấn của người dùng
#     def embed_query(self, text: str) -> list[float]:
#         segmented_text = self._segment_text(text)
#         return self.hf_embeddings.embed_query(segmented_text)

# %%
# Hướng tiếp cận mới: Sử dụng BGE-M3 (Không cần tách từ thủ công)
class BGEM3Embeddings(Embeddings):
    def __init__(self, model_name="BAAI/bge-m3"):
        # BGE-M3 thường cho ra vector size 1024 (lớn hơn PhoBERT là 768)
        self.hf_embeddings = HuggingFaceEmbeddings(
            model_name=model_name,
            model_kwargs={'device': 'cpu'} # Chuyển thành 'cuda' nếu bạn có GPU
        )

    def embed_documents(self, texts: list[str]) -> list[list[float]]:
        # Không dùng word_tokenize, đẩy trực tiếp text thô
        return self.hf_embeddings.embed_documents(texts)

    def embed_query(self, text: str) -> list[float]:
        return self.hf_embeddings.embed_query(text)

# %%
"""
Đoạn code bên dưới sẽ hoạt động theo các bước như sau:
- Bước 1: Trỏ đến thư mục chứa các metadata sản phẩm thời trang dưới dạng .jsonl, sau đó sẽ quét toàn bộ file và thực hiện chunking từng file một.
- Bước 2: Sau khi setup thành công Qdrant trên Docker, thì kết nối tới Qdrant đó thông qua địa chỉ ip local được cung cấp. Sau đó, tạo một collections 
          mới và thiết lập thông số cho vectors được lưu.
- Bước 3: Tiếp tục khởi tạo một VectorStore. VectorStore có nhiệm vụ số hóa các chunk tài liệu và lưu nó vào trong vector database đã được thiết lập.
"""
if __name__ == "__main__":
    # Trỏ đến thư mục chứa tất cả các file JSONL của bạn
    folder_path = "./Fashion_Metadata"

    # Khởi tạo Custom Embedding
    custom_embeddings = BGEM3Embeddings()

    if os.path.exists(folder_path):
        print(f"[THÔNG BÁO] Bắt đầu quét thư mục: {folder_path}\n" + "="*50)
        
        # Gọi hàm xử lý toàn bộ
        all_docs = process_all_directory(folder_path)
        
        print("="*50)
        print(f"[THÔNG BÁO] HOÀN TẤT! Tổng số lượng chunk (documents) thu được: {len(all_docs)}")

        qdrant_url = "http://localhost:6333"
        collection_name = "fashion_products_bge_m3"
        
        print(f"[THÔNG BÁO] Bắt đầu đẩy dữ liệu vào Qdrant tại: {qdrant_url}")
        
        client = QdrantClient(url=qdrant_url)
        
        # 1. KIỂM TRA SỐ LƯỢNG ĐÃ LƯU TRONG DATABASE
        if not client.collection_exists(collection_name):
            print(f"[THÔNG BÁO] Tạo mới collection '{collection_name}'...")
            client.create_collection(
                collection_name=collection_name,
                vectors_config=VectorParams(size=1024, distance=Distance.COSINE),
            )
            current_count = 0 # Chưa có gì
        else:
            # Lấy thông tin database hiện tại
            collection_info = client.get_collection(collection_name)
            current_count = collection_info.points_count # Số lượng vector đang có sẵn
            print(f"[THÔNG BÁO] Tìm thấy {current_count} sản phẩm đã được lưu trước đó.")
        
        # 2. CẮT BỎ PHẦN DỮ LIỆU ĐÃ LÀM XONG
        # Lấy từ vị trí current_count cho đến hết
        remaining_docs = all_docs[current_count:]
        
        if len(remaining_docs) == 0:
            print("\n[THÔNG BÁO] 🎉 Toàn bộ dữ liệu đã được xử lý xong từ trước. Không cần chạy lại!")
        else:
            print(f"[THÔNG BÁO] Bắt đầu nhúng và lưu {len(remaining_docs)} sản phẩm còn lại...")
            
            # Khởi tạo VectorStore
            vector_db = QdrantVectorStore(
                client=client,
                collection_name=collection_name,
                embedding=custom_embeddings,
            )
            
            batch_size = 128
            
            # 3. CHẠY THANH TIẾN TRÌNH CHO PHẦN CÒN LẠI
            # Tham số `initial` giúp thanh tiến trình không bắt đầu từ 0, mà hiển thị đúng phần trăm thực tế
            with tqdm(total=len(all_docs), initial=current_count, desc="Tiến độ Vector hóa", unit="SP") as pbar:
                for i in range(0, len(remaining_docs), batch_size):
                    # Cắt lô dữ liệu tiếp theo
                    batch = remaining_docs[i : i + batch_size]
                    
                    # Đẩy vào Qdrant
                    vector_db.add_documents(documents=batch)
                    
                    # Cập nhật thanh tiến trình
                    pbar.update(len(batch))
        
            print("\n[THÔNG BÁO] 🎉 ĐÃ LƯU HOÀN TẤT VÀO VECTOR DATABASE!")
        
    else:
        print(f"[THÔNG BÁO] Không tìm thấy thư mục {folder_path}. Vui lòng kiểm tra lại.")
# Out:
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# [THÔNG BÁO] Bắt đầu quét thư mục: ./Fashion_Metadata
# ==================================================
# [THÔNG BÁO] Đang đọc file: Fashion_Metadata_Ao.jsonl...
# [THÔNG BÁO] Đang đọc file: Fashion_Metadata_Ao_khoac.jsonl...
# [THÔNG BÁO] Đang đọc file: Fashion_Metadata_Bong_tai.jsonl...
# [THÔNG BÁO] Đang đọc file: Fashion_Metadata_Chan_vay.jsonl...
# [THÔNG BÁO] Đang đọc file: Fashion_Metadata_Dam.jsonl...
# [THÔNG BÁO] Đang đọc file: Fashion_Metadata_Day_chuyen.jsonl...
# [THÔNG BÁO] Đang đọc file: Fashion_Metadata_Do_lot.jsonl...
# [THÔNG BÁO] Đang đọc file: Fashion_Metadata_Dong_ho.jsonl...
# [THÔNG BÁO] Đang đọc file: Fashion_Metadata_Gang_tay.jsonl...
# [THÔNG BÁO] Đang đọc file: Fashion_Metadata_Ghim_cai_ao.jsonl...
# [THÔNG BÁO] Đang đọc file: Fashion_Metadata_Giay.jsonl...
# [THÔNG BÁO] Đang đọc file: Fashion_Metadata_Jumpsuit.jsonl...
# [THÔNG BÁO] Đang đọc file: Fashion_Metadata_Khac.jsonl...
# [THÔNG BÁO] Đang đọc file: Fashion_Metadata_Kinh_mat.jsonl...
# [THÔNG BÁO] Đang đọc file: Fashion_Metadata_Mu.jsonl...
# [THÔNG BÁO] Đang đọc file: Fashion_Metadata_Nhan.jsonl...
# [THÔNG BÁO] Đang đọc file: Fashion_Metadata_Phu_kien_ho_tro.jsonl...
# [THÔNG BÁO] Đang đọc file: Fashion_Metadata_Quan.jsonl...
# [THÔNG BÁO] Đang đọc file: Fashion_Metadata_Tui_xach.jsonl...
# [THÔNG BÁO] Đang đọc file: Fashion_Metadata_Vong_tay.jsonl...
# ==================================================
# [THÔNG BÁO] HOÀN TẤT! Tổng số lượng chunk (documents) thu được: 48938
# [THÔNG BÁO] Bắt đầu đẩy dữ liệu vào Qdrant tại: http://localhost:6333
# [THÔNG BÁO] Tìm thấy 2560 sản phẩm đã được lưu trước đó.
# [THÔNG BÁO] Bắt đầu nhúng và lưu 46378 sản phẩm còn lại...
# Tiến độ Vector hóa:  12%|█▏        | 5760/48938 [41:47<9:23:54,  1.28SP/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 71
#      68 batch = remaining_docs[i : i + batch_size]
#      70 # Đẩy vào Qdrant
# ---> 71 vector_db.add_documents(documents=batch)
#      73 # Cập nhật thanh tiến trình
#      74 pbar.update(len(batch))
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\langchain_core\vectorstores\base.py:258, in VectorStore.add_documents(self, documents, **kwargs)
#     256     texts = [doc.page_content for doc in documents]
#     257     metadatas = [doc.metadata for doc in documents]
# --> 258     return self.add_texts(texts, metadatas, **kwargs)
#     259 msg = (
#     260     f"`add_documents` and `add_texts` has not been implemented "
#     261     f"for {self.__class__.__name__} "
#     262 )
#     263 raise NotImplementedError(msg)
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\langchain_qdrant\qdrant.py:510, in QdrantVectorStore.add_texts(self, texts, metadatas, ids, batch_size, **kwargs)
#     503 """Add texts with embeddings to the `VectorStore`.
#     504
#     505 Returns:
#     506     List of ids from adding the texts into the `VectorStore`.
#     507
#     508 """
#     509 added_ids = []
# --> 510 for batch_ids, points in self._generate_batches(
#     511     texts, metadatas, ids, batch_size
#     512 ):
#     513     self.client.upsert(
#     514         collection_name=self.collection_name, points=points, **kwargs
#     515     )
#     516     added_ids.extend(batch_ids)
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\langchain_qdrant\qdrant.py:1060, in QdrantVectorStore._generate_batches(self, texts, metadatas, ids, batch_size)
#    1050 batch_metadatas = list(islice(metadatas_iterator, batch_size)) or None
#    1051 batch_ids = list(islice(ids_iterator, batch_size))
#    1052 points = [
#    1053     models.PointStruct(
#    1054         id=point_id,
#    1055         vector=vector,
#    1056         payload=payload,
#    1057     )
#    1058     for point_id, vector, payload in zip(
#    1059         batch_ids,
# -> 1060         self._build_vectors(batch_texts),
#    1061         self._build_payloads(
#    1062             batch_texts,
#    1063             batch_metadatas,
#    1064             self.content_payload_key,
#    1065             self.metadata_payload_key,
#    1066         ),
#    1067         strict=False,
#    1068     )
#    1069 ]
#    1071 yield batch_ids, points
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\langchain_qdrant\qdrant.py:1104, in QdrantVectorStore._build_vectors(self, texts)
#    1102 if self.retrieval_mode == RetrievalMode.DENSE:
#    1103     embeddings = self._require_embeddings("DENSE mode")
# -> 1104     batch_embeddings = embeddings.embed_documents(list(texts))
#    1105     return [
#    1106         {
#    1107             self.vector_name: vector,
#    1108         }
#    1109         for vector in batch_embeddings
#    1110     ]
#    1112 if self.retrieval_mode == RetrievalMode.SPARSE:
#
# Cell In[11], line 12, in BGEM3Embeddings.embed_documents(self, texts)
#      10 def embed_documents(self, texts: list[str]) -> list[list[float]]:
#      11     # Không dùng word_tokenize, đẩy trực tiếp text thô
# ---> 12     return self.hf_embeddings.embed_documents(texts)
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\langchain_huggingface\embeddings\huggingface.py:155, in HuggingFaceEmbeddings.embed_documents(self, texts)
#     145 def embed_documents(self, texts: list[str]) -> list[list[float]]:
#     146     """Compute doc embeddings using a HuggingFace transformer model.
#     147
#     148     Args:
#    (...)
#     153
#     154     """
# --> 155     return self._embed(texts, self.encode_kwargs)
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\langchain_huggingface\embeddings\huggingface.py:130, in HuggingFaceEmbeddings._embed(self, texts, encode_kwargs)
#     128     sentence_transformers.SentenceTransformer.stop_multi_process_pool(pool)
#     129 else:
# --> 130     embeddings = self._client.encode(
#     131         texts,
#     132         show_progress_bar=self.show_progress,
#     133         **encode_kwargs,
#     134     )
#     136 if isinstance(embeddings, list):
#     137     msg = (
#     138         "Expected embeddings to be a Tensor or a numpy array, "
#     139         "got a list instead."
#     140     )
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\sentence_transformers\SentenceTransformer.py:1094, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, truncate_dim, pool, chunk_size, **kwargs)
#    1091 features.update(extra_features)
#    1093 with torch.no_grad():
# -> 1094     out_features = self.forward(features, **kwargs)
#    1095     if self.device.type == "hpu":
#    1096         out_features = copy.deepcopy(out_features)
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\sentence_transformers\SentenceTransformer.py:1175, in SentenceTransformer.forward(self, input, **kwargs)
#    1169             module_kwarg_keys = self.module_kwargs.get(module_name, [])
#    1170         module_kwargs = {
#    1171             key: value
#    1172             for key, value in kwargs.items()
#    1173             if key in module_kwarg_keys or (hasattr(module, "forward_kwargs") and key in module.forward_kwargs)
#    1174         }
# -> 1175     input = module(input, **module_kwargs)
#    1176 return input
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\sentence_transformers\models\Transformer.py:262, in Transformer.forward(self, features, **kwargs)
#     239 """
#     240 Forward pass through the transformer model.
#     241
#    (...)
#     258         - 'all_layer_embeddings': If the model outputs hidden states, contains embeddings from all layers
#     259 """
#     260 trans_features = {key: value for key, value in features.items() if key in self.model_forward_params}
# --> 262 outputs = self.auto_model(**trans_features, **kwargs, return_dict=True)
#     263 token_embeddings = outputs[0]
#     264 features["token_embeddings"] = token_embeddings
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\transformers\utils\generic.py:952, in merge_with_config_defaults.<locals>.wrapper(self, *args, **kwargs)
#     950             output = func(self, *args, **kwargs)
#     951     else:
# --> 952         output = func(self, *args, **kwargs)
#     953 # Restore original config value
#     954 finally:
#     955     if is_causal is not None:
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\transformers\utils\output_capturing.py:248, in capture_outputs.<locals>.wrapped_fn.<locals>.wrapper(self, *args, **kwargs)
#     246 # Run the forward
#     247 try:
# --> 248     outputs = func(self, *args, **kwargs)
#     249 # Reset the states
#     250 finally:
#     251     _active_collector.reset(output_token)
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\transformers\models\xlm_roberta\modeling_xlm_roberta.py:641, in XLMRobertaModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, **kwargs)
#     625 embedding_output = self.embeddings(
#     626     input_ids=input_ids,
#     627     position_ids=position_ids,
#    (...)
#     630     past_key_values_length=past_key_values_length,
#     631 )
#     633 attention_mask, encoder_attention_mask = self._create_attention_masks(
#     634     attention_mask=attention_mask,
#     635     encoder_attention_mask=encoder_attention_mask,
#    (...)
#     638     past_key_values=past_key_values,
#     639 )
# --> 641 encoder_outputs = self.encoder(
#     642     embedding_output,
#     643     attention_mask=attention_mask,
#     644     encoder_hidden_states=encoder_hidden_states,
#     645     encoder_attention_mask=encoder_attention_mask,
#     646     past_key_values=past_key_values,
#     647     use_cache=use_cache,
#     648     position_ids=position_ids,
#     649     **kwargs,
#     650 )
#     651 sequence_output = encoder_outputs.last_hidden_state
#     652 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\transformers\models\xlm_roberta\modeling_xlm_roberta.py:535, in XLMRobertaEncoder.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, **kwargs)
#     524 def forward(
#     525     self,
#     526     hidden_states: torch.Tensor,
#    (...)
#     532     **kwargs: Unpack[TransformersKwargs],
#     533 ) -> tuple[torch.Tensor] | BaseModelOutputWithPastAndCrossAttentions:
#     534     for i, layer_module in enumerate(self.layer):
# --> 535         hidden_states = layer_module(
#     536             hidden_states,
#     537             attention_mask,
#     538             encoder_hidden_states,  # as a positional argument for gradient checkpointing
#     539             encoder_attention_mask=encoder_attention_mask,
#     540             past_key_values=past_key_values,
#     541             **kwargs,
#     542         )
#     544     return BaseModelOutputWithPastAndCrossAttentions(
#     545         last_hidden_state=hidden_states,
#     546         past_key_values=past_key_values if use_cache else None,
#     547     )
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\transformers\modeling_layers.py:93, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      90         logger.warning_once(message)
#      92     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 93 return super().__call__(*args, **kwargs)
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\transformers\models\xlm_roberta\modeling_xlm_roberta.py:459, in XLMRobertaLayer.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, **kwargs)
#     449     cross_attention_output, _ = self.crossattention(
#     450         self_attention_output,
#     451         None,  # attention_mask
#    (...)
#     455         **kwargs,
#     456     )
#     457     attention_output = cross_attention_output
# --> 459 layer_output = apply_chunking_to_forward(
#     460     self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     461 )
#     462 return layer_output
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\transformers\pytorch_utils.py:201, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     198     # concatenate output at same dimension
#     199     return torch.cat(output_chunks, dim=chunk_dim)
# --> 201 return forward_fn(*input_tensors)
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\transformers\models\xlm_roberta\modeling_xlm_roberta.py:465, in XLMRobertaLayer.feed_forward_chunk(self, attention_output)
#     464 def feed_forward_chunk(self, attention_output):
# --> 465     intermediate_output = self.intermediate(attention_output)
#     466     layer_output = self.output(intermediate_output, attention_output)
#     467     return layer_output
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\transformers\models\xlm_roberta\modeling_xlm_roberta.py:386, in XLMRobertaIntermediate.forward(self, hidden_states)
#     385 def forward(self, hidden_states: torch.Tensor) -> torch.Tensor:
# --> 386     hidden_states = self.dense(hidden_states)
#     387     hidden_states = self.intermediate_act_fn(hidden_states)
#     388     return hidden_states
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %% [markdown]
# # 4. Xây dựng Retriever để truy hồi dữ liệu

# %%
def load_vector_db():
    print("[THÔNG BÁO] Đang khởi tạo mô hình Embedding...")
    custom_embeddings = BGEM3Embeddings()
    
    print("[THÔNG BÁO] Đang kết nối tới Qdrant Database...")
    # qdrant_url = "http://localhost:6333"
    # client = QdrantClient(url=qdrant_url)
    client = QdrantClient(path="./qdrant_data")
    # Khởi tạo QdrantVectorStore và gán vào biến vector_db
    vector_db = QdrantVectorStore(
        client=client,
        collection_name="fashion_products_bge_m3",
        embedding=custom_embeddings
    )
    
    print("✅ Đã kết nối thành công!")
    return vector_db

# Sử dụng trong file Chatbot
if __name__ == "__main__":
    vector_db = load_vector_db()

    # Thiết lập retriever để truy hồi thông tin
    retriever = vector_db.as_retriever(
        search_type="similarity_score_threshold", # Tìm kiếm theo độ tương đồng Vector dựa trên một ngưỡng
        search_kwargs={"k": 5, # "k" là số lượng kết quả bạn muốn lấy ra
                       "score_threshold": 0.7 # Chỉ lấy ra các sản phẩm có độ tương đồng Vector từ 70% trở lên
                      }    
    )
    
    print("[THÔNG BÁO] Đã khởi tạo Retriever thành công!")
# Out:
# [THÔNG BÁO] Đang khởi tạo mô hình Embedding...
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# [THÔNG BÁO] Đang kết nối tới Qdrant Database...
# C:\Users\DELL\AppData\Local\Temp\ipykernel_25448\1350268014.py:8: UserWarning: Local mode is not recommended for collections with more than 20,000 points. Collection <fashion_products_bge_m3> contains 48938 points. Consider using Qdrant in Docker or Qdrant Cloud for better performance with large datasets.
#   client = QdrantClient(path="./qdrant_data")
# ✅ Đã kết nối thành công!
# [THÔNG BÁO] Đã khởi tạo Retriever thành công!

# %% [markdown]
# # 5. Khởi tạo LLM để tích hợp vào hệ thống Chatbot

# %%
print("[THÔNG BÁO] Đang khởi tạo mô hình Qwen local...")
llm = ChatOllama(
    # model="qwen3:4b-instruct", 
    model="qwen2.5:3b-instruct",
    temperature=0.4,
    timeout=120,
    num_predict=350,
    num_ctx=8192,
)
print("[THÔNG BÁO] Đã khởi tạo LLM thành công!")
# Out:
# [THÔNG BÁO] Đang khởi tạo mô hình Qwen local...
# [THÔNG BÁO] Đã khởi tạo LLM thành công!

# %% [markdown]
# # 6. Cấu hình Prompt và Redis

# %%
# 1. Kịch bản chính cho Chatbot (Chống Bịa Đặt & Trích Xuất Chính Xác)
system_prompt = """Bạn là chuyên viên tư vấn thời trang cao cấp của shop.

QUY TẮC TỐI CAO (CHỐNG BỊA ĐẶT - ANTI-HALLUCINATION):
1. CHỈ SỬ DỤNG thông tin có trong phần "DỮ LIỆU SẢN PHẨM" bên dưới để trả lời.
2. TUYỆT ĐỐI KHÔNG tự bịa ra tên sản phẩm, không bịa ID, giá tiền, màu sắc hay chất liệu. 
3. NẾU KHÔNG TÌM THẤY SẢN PHẨM KHỚP NHU CẦU: Khẳng định ngay là shop chưa có mẫu này, xin lỗi và mời khách xem mẫu khác. Không được cố gắng đoán hoặc bịa ra sản phẩm.

QUY TẮC TRÍCH XUẤT VÀ ĐỊNH DẠNG:
4. BẮT BUỘC TRÍCH XUẤT CHÍNH XÁC 100%: Khi giới thiệu một sản phẩm, bạn PHẢI copy y nguyên trường [Sản phẩm] và [MÃ_SP] từ dữ liệu. Không thêm, không bớt, không dịch thuật.
5. TRÌNH BÀY BẮT BUỘC theo khuôn mẫu sau:
   - **[TÊN_SP]** (Mã SP: [MÃ_SP])
   - Giá: [GIÁ_TIỀN] VNĐ
   - Đặc điểm chi tiết: Lấy ra các thông tin về đặc điểm chi tiết của sản phẩm (màu sắc, chất liệu, kích cỡ, họa tiết) và dựa vào nó để VIẾT THÀNH MỘT CÂU HOÀN CHỈNH, KHÔNG ĐƯỢC BỊA ĐẶT THÔNG TIN.
   - (Viết 1-2 câu tư vấn thân thiện, khen ngợi sản phẩm dựa trên đặc điểm và mô tả chi tiết của nó)
6. GIỚI HẠN: Trả lời tự nhiên, thân thiện nhưng không vượt quá 200 từ.

DỮ LIỆU SẢN PHẨM:
{context}"""

QA_PROMPT = ChatPromptTemplate.from_messages([
    ("system", system_prompt),
    MessagesPlaceholder("chat_history"), 
    ("human", "{input}")
])

REDIS_URL = "redis://localhost:6379"

def get_message_history(session_id: str):
    history = RedisChatMessageHistory(session_id, url=REDIS_URL)
    current_messages = history.messages
    if len(current_messages) > 6: 
        kept_messages = current_messages[-6:]
        history.clear()
        history.add_messages(kept_messages)
    return history

print("[THÔNG BÁO] Đã cấu hình Kịch bản chuẩn ChatML và Redis thành công!")
# Out:
# [THÔNG BÁO] Đã cấu hình Kịch bản chuẩn ChatML và Redis thành công!

# %% [markdown]
# # 7. Xây dựng kiến trúc RAG

# %%
print("[THÔNG BÁO] Đang lắp ráp Pipeline Retriever Thông minh...")

# 1. KỊCH BẢN PHỤ: Dạy AI cách viết lại câu hỏi
contextualize_q_system_prompt = """BẠN LÀ MỘT CÔNG CỤ VIẾT LẠI CÂU TRUY VẤN, BẠN KHÔNG PHẢI LÀ CHATBOT.
Nhiệm vụ: Đọc "Lịch sử trò chuyện" và "Câu hỏi mới", VIẾT nó thành MỘT CÂU TRUY VẤN HOÀN CHỈNH.

QUY TẮC TUYỆT ĐỐI:
1. CHỈ IN RA CÂU TRUY VẤN HOÀN CHỈNH. TUYỆT ĐỐI không thực hiện những nhiệm vụ khác mà không liên quan tới VAI TRÒ của bạn.
2. Nếu đầu vào KHÔNG PHẢI CÂU TRUY VẤN của người dùng thì TRẢ VỀ CÂU TRUY VẤN GỐC.
3. Nếu đầu vào LÀ CÂU TRUY VẤN của người dùng, nhưng bạn KHÔNG CHẮC CHẮN trong việc viết lại câu truy vấn thì TRẢ VỀ CÂU TRUY VẤN GỐC.

VÍ DỤ BẮT BUỘC TUÂN THỦ:
- Khách: Có áo sơ mi trắng nam không? -> Kết quả: Cửa hàng có bán áo sơ mi trắng nam không?
- Lịch sử: Khách vừa hỏi về "Shop có áo thun nam màu đỏ không". Khách hỏi tiếp: Có size XL không? -> Kết quả: Áo thun nam màu đỏ mà Shop bán có size XXL không?
"""

contextualize_q_prompt = ChatPromptTemplate.from_messages([
    ("system", contextualize_q_system_prompt),
    MessagesPlaceholder("chat_history"),
    ("human", "{input}"),
])

document_prompt_template = """
[MÃ_SP: {product_id}]
THÔNG TIN CHI TIẾT: {page_content}
"""
doc_prompt = PromptTemplate.from_template(document_prompt_template)

# 2. KHỞI TẠO CÁC CHUỖI RAG
# Chuỗi 1: Trợ lý viết lại câu hỏi
history_aware_retriever = create_history_aware_retriever(
    llm, retriever, contextualize_q_prompt
)

# Chuỗi 2: Nhồi dữ liệu từ Qdrant vào Kịch bản chính (QA_PROMPT ở Cell 6)
document_chain = create_stuff_documents_chain(llm=llm, prompt=QA_PROMPT, document_prompt=doc_prompt)

# Chuỗi 3: Ghép nối Trợ lý viết lại câu vào hệ thống
rag_chain = create_retrieval_chain(history_aware_retriever, document_chain)

# 4. TRÙM REDIS ĐỂ LƯU LỊCH SỬ
full_chat_chain = RunnableWithMessageHistory(
    rag_chain,
    get_message_history,
    input_messages_key="input",
    history_messages_key="chat_history",
    output_messages_key="answer",
)

print("[THÔNG BÁO] Hệ thống Retriever Thông minh đã sẵn sàng!")
# Out:
# [THÔNG BÁO] Đang lắp ráp Pipeline Retriever Thông minh...
# [THÔNG BÁO] Hệ thống Retriever Thông minh đã sẵn sàng!

# %% [markdown]
# # 8. Luồng chạy chính

# %%
SESSION_ID = str(uuid.uuid4()) 
# 1. TẠO "CAMERA" GIÁM SÁT RETRIEVER
class SpyRetrieverHandler(BaseCallbackHandler):
    # Hàm này sẽ tự động kích hoạt ngay trước khi Qdrant đi tìm dữ liệu
    def on_retriever_start(self, serialized: dict, query: str, **kwargs):
        # 'query' ở đây chính là thành phẩm đã được llm viết lại dựa trên lịch sử
        print(f"\n🕵️‍♂️ [AI ĐÃ VIẾT LẠI CÂU HỎI THÀNH]: {query}\n")

print("="*60)
print(" 👗👔 CHATBOT TƯ VẤN THỜI TRANG ĐÃ SẴN SÀNG 👔👗 ")
print("       (Nhập '0' rồi Enter để kết thúc)       ")
print("="*60 + "\n")

# Vòng lặp vô tận (cho đến khi gặp lệnh break)
while True:
    user_input = input("👤 Bạn: ")
    
    if user_input.strip() == "0":
        print("\n🤖 Chatbot: Dạ, cảm ơn bạn đã ghé thăm shop. Hẹn gặp lại bạn nhé!")
        break
        
    if not user_input.strip():
        continue
        
    print("🤖 Chatbot: ", end="")

    start_time = time.time()
    first_token_time = None
    
    try:
        # 2. GẮN CAMERA VÀO LUỒNG STREAM
        for chunk in full_chat_chain.stream(
            {"input": user_input},
            config={
                "configurable": {"session_id": SESSION_ID},
                "callbacks": [SpyRetrieverHandler()]  # <--- Gắn camera vào đây
            }
        ):
            if "answer" in chunk:
                if first_token_time is None:
                    first_token_time = time.time()
                print(chunk["answer"], end="", flush=True)

        end_time = time.time()
        
        # Đề phòng trường hợp lỗi không sinh ra chữ nào
        if first_token_time is None:
            first_token_time = end_time
            
        ttft = first_token_time - start_time
        total_time = end_time - start_time
        
        # In bảng thống kê nhỏ sau mỗi câu trả lời
        print(f"\n\n⏱️ [THỐNG KÊ TỐC ĐỘ]:")
        print(f"   - Nhả chữ đầu tiên sau: {ttft:.2f} giây")
        print(f"   - Hoàn thành toàn bộ sau: {total_time:.2f} giây")
                
    except Exception as e:
        print(f"\n[LỖI HỆ THỐNG] Đã xảy ra sự cố: {e}")
        
    print("\n\n" + "-"*60 + "\n")
# Out:
# ============================================================
#  👗👔 CHATBOT TƯ VẤN THỜI TRANG ĐÃ SẴN SÀNG 👔👗
#        (Nhập '0' rồi Enter để kết thúc)
# ============================================================
#
# 🤖 Chatbot:
# 🕵️‍♂️ [AI ĐÃ VIẾT LẠI CÂU HỎI THÀNH]: xin chào
#
# Xin chào! Tôi có thể giúp bạn tìm sản phẩm nào không?
#
# ⏱️ [THỐNG KÊ TỐC ĐỘ]:
#    - Nhả chữ đầu tiên sau: 63.56 giây
#    - Hoàn thành toàn bộ sau: 65.59 giây
#
#
# ------------------------------------------------------------
#
# 🤖 Chatbot:
# 🕵️‍♂️ [AI ĐÃ VIẾT LẠI CÂU HỎI THÀNH]: Tại sao bạn muốn mua một chiếc váy?
#
# **[Thảm họa]** (Mã SP: B0B9R3P94M)
# Giá: 719760 VNĐ
# **TÊN_SP:** Váy nữ Alaster
# Đặc điểm chi tiết: có các loại màu sắc, chất liệu Rayon, Polyester, Spandex, kích cỡ Kích cỡ tự do, họa tiết .
# Phù hợp sử dụng cho Quanh năm và các dịp ['Hàng ngày']. Chiếc váy nữ Alaster với thiết kế thắt dây tinh tế. Sản phẩm được làm từ chất liệu vải pha thoải mái, phù hợp cho nhiều dịp khác nhau.
#
# ⏱️ [THỐNG KÊ TỐC ĐỘ]:
#    - Nhả chữ đầu tiên sau: 116.04 giây
#    - Hoàn thành toàn bộ sau: 138.02 giây
#
#
# ------------------------------------------------------------
#
#
# 🤖 Chatbot: Dạ, cảm ơn bạn đã ghé thăm shop. Hẹn gặp lại bạn nhé!
